# %% [markdown]
# ## 4) What attacks were successful?
# a. What determines a successful attack? Explain.
# b. Support your decision(s).
#
# 1. Snort is not a honeypot but an IDS/IPS and is used to detect attacks.
# 2. Dionaea is a low interaction honeypot that exposes services such as MSSQL, SIP, HTTP, FTP, TFTP, SFTP, SSH, and SMB.
# 3. Cowrie is a medium interaction SSH honeypot designed to log brute force attacks and shell interactions performed by the attackers.
# 4. **Elastishoney is a simple elasticsearch honeypot designed to catch attackers exploiting remote code execution (RCE) vulnerabilities in elasticsearch.**
# 5. Glastopf is a Python based Web application honeypot that has the ability to emulate thousands of web vulnerabilities.
# 6. Wordpot is a WordPress emulator honeypot.
# 7. ShockPot is a web application honeypot that exposes the vulnerability CVE-2014-6271

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 100)
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# ## ElasticHoney

# %%
df = pd.read_csv("sorted-elastichoney.csv",sep='\t',dtype='str')

# %%
df.sample(1)
# Out:
#                           id                                 ident normalized  \
# 31  58ff479393e0950608bfb025  78169b80-5ce8-11e6-94de-0800272a9814       True
#
#                   timestamp   unixTimestamp    cal_date week day  year month  \
# 31  2017-04-25 08:56:51.399  1493110611.399  2017-04-25      Tue  2017     4
#
#    day hour minutes             seconds              channel      source_ip  \
# 31  25    8      56  51.398999999999994  elastichoney.events  171.92.208.42
#
#    source_ip_num source_port destination_ip destination_ip_num  \
# 31    2874986538        None   192.168.10.6         3232238086
#
#    destination_port protocol     city province province_code country  \
# 31             9200     None  Chengdu  Sichuan            SC   China
#
#    country_code continent latitude longitude  \
# 31           CN      Asia  30.6667  104.0667
#
#                                               asn method    type  \
# 31  CHINANET SiChuan Telecom Internet Data Center    GET  attack
#
#                                                   URL  \
# 31  192.168.10.6:9200/_search?source={"size":1,"qu...
#
#                                                  form  \
# 31  source={"size":1,"query":{"filtered":{"query":...
#
#                                            user_agent Payload Connection  \
# 31  Mozilla/4.0 (compatible; MSIE 6.0; Windows NT ...                NaN
#
#    Payload Payload Resource Payload MD5
# 31     NaN              NaN         NaN

# %%
dfe=df[['timestamp','channel','source_ip','destination_port',
        'protocol','city','country','asn','method','type',
        'URL','form','user_agent','Payload Connection','Payload','Payload Resource','Payload MD5']]

# %% [markdown]
# ***

# %%
dfe[~dfe['Payload Connection'].isna()]
# Out:
#                   timestamp              channel      source_ip  \
# 14  2017-01-17 06:58:27.420  elastichoney.events  123.249.27.46
# 15  2017-01-17 06:58:39.185  elastichoney.events  123.249.27.46
# 32  2017-04-25 08:56:58.721  elastichoney.events  171.92.208.42
# 33  2017-04-25 08:57:08.833  elastichoney.events  171.92.208.42
# 39  2017-04-25 17:53:46.350  elastichoney.events  171.92.208.42
# 45  2017-04-25 19:59:16.705  elastichoney.events  171.92.208.42
# 54  2017-06-30 15:04:00.001  elastichoney.events  222.186.134.8
# 55  2017-06-30 15:04:01.073  elastichoney.events  222.186.134.8
#
#    destination_port protocol      city country  \
# 14             9200     None  Shenzhen   China
# 15             9200     None  Shenzhen   China
# 32             9200     None   Chengdu   China
# 33             9200     None   Chengdu   China
# 39             9200     None   Chengdu   China
# 45             9200     None   Chengdu   China
# 54             9200     None   Nanjing   China
# 55             9200     None   Nanjing   China
#
#                                                  asn method    type  \
# 14                            No.31 -Jin-rong Street    GET  attack
# 15                            No.31 -Jin-rong Street    GET  attack
# 32     CHINANET SiChuan Telecom Internet Data Center    GET  attack
# 33     CHINANET SiChuan Telecom Internet Data Center    GET  attack
# 39     CHINANET SiChuan Telecom Internet Data Center    GET  attack
# 45     CHINANET SiChuan Telecom Internet Data Center    GET  attack
# 54  AS Number for CHINANET jiangsu province backbone    GET  attack
# 55  AS Number for CHINANET jiangsu province backbone    GET  attack
#
#                                                   URL  \
# 14  192.168.10.4:9200/_search?source={"size":1,"qu...
# 15  192.168.10.4:9200/_search?source={"size":1,"qu...
# 32  192.168.10.6:9200/_search?source={"size":1,"qu...
# 33  192.168.10.6:9200/_search?source={"size":1,"qu...
# 39  192.168.10.6:9200/_search?source={"size":1,"qu...
# 45  192.168.10.6:9200/_search?source={"size":1,"qu...
# 54  192.168.10.4:9200/_search?source={"size":1,"qu...
# 55  192.168.10.4:9200/_search?source={"size":1,"qu...
#
#                                                  form  \
# 14  source={"size":1,"query":{"filtered":{"query":...
# 15  source={"size":1,"query":{"filtered":{"query":...
# 32  source={"size":1,"query":{"filtered":{"query":...
# 33  source={"size":1,"query":{"filtered":{"query":...
# 39  source={"size":1,"query":{"filtered":{"query":...
# 45  source={"size":1,"query":{"filtered":{"query":...
# 54  source={"size":1,"query":{"filtered":{"query":...
# 55  source={"size":1,"query":{"filtered":{"query":...
#
#                                            user_agent Payload Connection  \
# 14  Mozilla/4.0 (compatible; MSIE 6.0; Windows NT ...               curl
# 15  Mozilla/4.0 (compatible; MSIE 6.0; Windows NT ...               wget
# 32  Mozilla/4.0 (compatible; MSIE 6.0; Windows NT ...               curl
# 33  Mozilla/4.0 (compatible; MSIE 6.0; Windows NT ...               wget
# 39  Mozilla/4.0 (compatible; MSIE 6.0; Windows NT ...               wget
# 45  Mozilla/4.0 (compatible; MSIE 6.0; Windows NT ...               wget
# 54  Mozilla/4.0 (compatible; MSIE 6.0; Windows NT ...               wget
# 55  Mozilla/4.0 (compatible; MSIE 6.0; Windows NT ...               curl
#
#    Payload                   Payload Resource  \
# 14     NaN          http://116.48.48.14/cysip
# 15     NaN          http://116.48.48.14/cysip
# 32     NaN  http://27.151.13.170:1234/JrLinux
# 33     NaN  http://27.151.13.170:1234/JrLinux
# 39     NaN  http://27.151.13.170:1234/JrLinux
# 45     NaN  http://27.151.13.170:1234/JrLinux
# 54     NaN     http://107.151.137.226:5648/qw
# 55     NaN                            /tmp/qw
#
#                          Payload MD5
# 14  c9102cab70a8ad53ab4406ccbb3f2f99
# 15  c9102cab70a8ad53ab4406ccbb3f2f99
# 32  f8008d5f58cf0dd3035ced776c2df284
# 33  f8008d5f58cf0dd3035ced776c2df284
# 39  f8008d5f58cf0dd3035ced776c2df284
# 45  f8008d5f58cf0dd3035ced776c2df284
# 54  8ff6cd6cb0e95a3c970adf56e7537a96
# 55                               NaN
