# %% [markdown]
# ## 4) What attacks were successful?
# a. What determines a successful attack? Explain.
# b. Support your decision(s).
#
# - Snort is not a honeypot but an IDS/IPS and is used to detect attacks.
# - Dionaea is a low interaction honeypot that exposes services such as MSSQL, SIP, HTTP, FTP, TFTP, SFTP, SSH, and SMB.
# - **Cowrie is a medium interaction SSH honeypot designed to log brute force attacks and shell interactions performed by the attackers.**
# - Elastishoney is a simple elasticsearch honeypot designed to catch attackers exploiting remote code execution (RCE) vulnerabilities in elasticsearch.
# - Glastopf is a Python based Web application honeypot that has the ability to emulate thousands of web vulnerabilities.
# - Wordpot is a WordPress emulator honeypot.
# - ShockPot is a web application honeypot that exposes the vulnerability CVE-2014-6271

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 100)
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# ## Cowrie

# %%
df = pd.read_csv("sorted-cowrie.csv",sep='\t',dtype='str')

# %%
dfc=df[['timestamp','channel','source_ip','destination_port','protocol','city','country','asn','commands','loggedin','version','ttylog','urls','payload_startTime','payload_endTime','credentials']]

# %%
dfc.sample(1)
# Out:
#                      timestamp          channel       source_ip  \
# 55915  2017-06-26 22:57:47.429  cowrie.sessions  221.194.47.233
#
#       destination_port protocol   city country  \
# 55915               22      SSH  Hebei   China
#
#                                   asn commands loggedin        version ttylog  \
# 55915  CHINA UNICOM China169 Backbone       []     None  SSH-2.0-PUTTY   None
#
#        urls      payload_startTime        payload_endTime  \
# 55915  None  2017-06-26 22:58:05.4  2017-06-26 22:58:10.7
#
#                                              credentials
# 55915  [['root', 'pancake1'], ['root', 'paint'], ['ro...

# %%
dfc_accept = dfc[dfc.loggedin != "None"]
dfc_accept
# Out:
#                      timestamp          channel       source_ip  \
# 686    2016-09-26 00:38:21.469  cowrie.sessions  218.87.109.248
# 1204   2016-09-26 12:01:42.341  cowrie.sessions   149.56.24.204
# 73269  2017-07-15 07:25:59.468  cowrie.sessions   218.65.30.122
# 75510  2017-07-15 16:06:28.292  cowrie.sessions   61.177.172.19
# 77849  2017-07-16 06:18:07.221  cowrie.sessions    59.63.166.80
# 79362  2017-07-16 12:15:10.930  cowrie.sessions    158.69.79.38
# 80567  2017-07-17 02:11:21.126  cowrie.sessions    158.69.79.35
# 80648  2017-07-17 02:30:18.862  cowrie.sessions    158.69.79.38
#
#       destination_port protocol      city country  \
# 686                 22      SSH  Nanchang   China
# 1204                22      SSH  Montreal  Canada
# 73269               22      SSH  Shangrao   China
# 75510               22      SSH   Nanjing   China
# 77849               22      SSH  Nanchang   China
# 79362               22      SSH  Montreal  Canada
# 80567               22      SSH  Montreal  Canada
# 80648               22      SSH  Montreal  Canada
#
#                                         asn  \
# 686                  No.31 -Jin-rong Street
# 1204                                OVH SAS
# 73269                No.31 -Jin-rong Street
# 75510                No.31 -Jin-rong Street
# 77849  CHINANET Jiangx province IDC network
# 79362                               OVH SAS
# 80567                               OVH SAS
# 80648                               OVH SAS
#
#                                  commands            loggedin  \
# 686                                    []  ['root', '135790']
# 1204   ['echo InstallOK', 'cd /', 'pwd ']  ['root', '135790']
# 73269                                  []  ['root', '135790']
# 75510                                  []  ['root', '135790']
# 77849                                  []  ['root', '135790']
# 79362                                  []  ['root', '135790']
# 80567                                  []  ['root', '135790']
# 80648                                  []  ['root', '135790']
#
#                                                  version  \
# 686    SSH-2.0-nsssh2_4.0.0032 NetSarang Computer - Inc.
# 1204                                SSH-2.0-libssh-0.6.0
# 73269                                      SSH-2.0-PuTTY
# 75510                     SSH-2.0-OpenSSH_6.2p2 Ubuntu-6
# 77849                                      SSH-2.0-PuTTY
# 79362                     SSH-2.0-OpenSSH_6.9p1 Ubuntu-2
# 80567                     SSH-2.0-OpenSSH_7.2p2 Debian-5
# 80648                     SSH-2.0-OpenSSH_6.9p1 Ubuntu-2
#
#                                                   ttylog  urls  \
# 686                                                 None  None
# 1204   010000000000000000000000000000004d46e957c2b00e...  None
# 73269                                               None  None
# 75510                                               None  None
# 77849                                               None  None
# 79362  0100000000000000000000000000000030916b59ebcb00...  None
# 80567  010000000000000000000000000000002a556c59413103...  None
# 80648  010000000000000000000000000000009b596c59f4520e...  None
#
#            payload_startTime        payload_endTime  \
# 686    2016-09-26 00:37:31.8  2016-09-26 00:38:01.0
# 1204   2016-09-26 12:01:14.3  2016-09-26 12:01:18.2
# 73269  2017-07-15 07:26:05.9  2017-07-15 07:26:33.4
# 75510  2017-07-15 16:06:35.0  2017-07-15 16:07:02.0
# 77849  2017-07-16 06:18:18.7  2017-07-16 06:18:40.7
# 79362  2017-07-16 12:15:42.5  2017-07-16 12:15:44.3
# 80567  2017-07-17 02:11:52.6  2017-07-17 02:11:54.2
# 80648  2017-07-17 02:30:50.4  2017-07-17 02:30:51.9
#
#                                              credentials
# 686    [['root', 'connect'], ['root', 'daniel123'], [...
# 1204                                      [['root', '']]
# 73269  [['root', 'admin2013'], ['root', '789987'], ['...
# 75510  [['root', 'connect'], ['root', 'daniel123'], [...
# 77849  [['root', '7ujm,ki8'], ['root', '7x24'], ['roo...
# 79362                                     [['root', '']]
# 80567                                     [['root', '']]
# 80648                                     [['root', '']]
